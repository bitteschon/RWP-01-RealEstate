# %%
from tqdm import tqdm
import pandas as pd
import numpy as np
import datetime

# %%
def price_table(yr):
    path=r'price/아파트(매매)_실거래가_{}.xlsx'.format(yr)
    price_title = pd.read_excel(path, sheet_name = '아파트 매매 실거래가')
    return price_title

# %%
# %%time
d={}
for i in tqdm(range(2006,2020)):
    d['price_{}'.format(i)] = price_table(i)
    
#     price_title = 'price_'+ '{}'.format(i)
# #     price_table(i)
#     'price_{0}'.format(i) = price_table(i)
# Out:
# 100%|██████████| 14/14 [01:56<00:00,  8.30s/it]
# CPU times: user 1min 55s, sys: 588 ms, total: 1min 55s
# Wall time: 1min 56s

# %%
d
# Out:
# {'price_2006':                   시군구      번지   본번  부번             단지명  전용면적(㎡)    계약년월  계약일  \
#  0       서울특별시 강남구 개포동   655-2  655   2  개포2차현대아파트(220)    77.75  200603   10
#  1       서울특별시 강남구 개포동   655-2  655   2  개포2차현대아파트(220)    77.75  200603   29
#  2       서울특별시 강남구 개포동   655-2  655   2  개포2차현대아파트(220)    77.75  200604   29
#  3       서울특별시 강남구 개포동   655-2  655   2  개포2차현대아파트(220)    77.75  200606    1
#  4       서울특별시 강남구 개포동   655-2  655   2  개포2차현대아파트(220)    77.75  200610   20
#  ...               ...     ...  ...  ..             ...      ...     ...  ...
#  120796  서울특별시 중랑구 중화동     450  450   0             한신2    84.03  200612   19
#  120797  서울특별시 중랑구 중화동  274-51  274  51         한영(101)    57.66  200605   18
#  120798  서울특별시 중랑구 중화동  274-75  274  75         한영(102)    66.54  200611   17
#  120799  서울특별시 중랑구 중화동  274-77  274  77         한영(104)    68.32  200609   11
#  120800  서울특별시 중랑구 중화동  274-77  274  77         한영(104)    68.32  200611   28
#
# ...

# %%
price_2006=d['price_2006']
price_2007=d['price_2007']
price_2008=d['price_2008']
price_2009=d['price_2009']
price_2010=d['price_2010']
price_2011=d['price_2011']
price_2012=d['price_2012']
price_2013=d['price_2013']
price_2014=d['price_2014']
price_2015=d['price_2015']
price_2016=d['price_2016']
price_2017=d['price_2017']
price_2018=d['price_2018']
price_2019=d['price_2019']

# %%
raw_data=pd.concat([price_2006, price_2007, price_2008, price_2009, price_2010,
           price_2011, price_2012, price_2013, price_2014, price_2015, 
            price_2016, price_2017, price_2018, price_2019], ignore_index=True,sort=False)
raw_data
# Out:
#                    시군구      번지   본번  부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0        서울특별시 강남구 개포동   655-2  655   2  개포2차현대아파트(220)    77.75  200603   10
# 1        서울특별시 강남구 개포동   655-2  655   2  개포2차현대아파트(220)    77.75  200603   29
# 2        서울특별시 강남구 개포동   655-2  655   2  개포2차현대아파트(220)    77.75  200604   29
# 3        서울특별시 강남구 개포동   655-2  655   2  개포2차현대아파트(220)    77.75  200606    1
# 4        서울특별시 강남구 개포동   655-2  655   2  개포2차현대아파트(220)    77.75  200610   20
# ...                ...     ...  ...  ..             ...      ...     ...  ...
# 1061830  서울특별시 중랑구 중화동     450  450   0             한신2    59.76  201908    8
# 1061831  서울특별시 중랑구 중화동  274-51  274  51         한영(101)    84.69  201909    3
# 1061832  서울특별시 중랑구 중화동  274-75  274  75         한영(102)    57.18  201905   20
# 1061833  서울특별시 중랑구 중화동      11   11   0           현대휴앤미    82.17  201901   31
# 1061834  서울특별시 중랑구 중화동    11-7   11   7     현대휴앤미(102동)    64.48  201907   15
#
# ...

# %%
raw_data.columns
# Out:
# Index(['시군구', '번지', '본번', '부번', '단지명', '전용면적(㎡)', '계약년월', '계약일', '거래금액(만원)',
#        '층', '건축년도', '도로명'],
#       dtype='object')

# %%
raw_data['시'] = raw_data['시군구'].str.split(" ").str[0]
raw_data['구'] = raw_data['시군구'].str.split(" ").str[1]
raw_data['동'] = raw_data['시군구'].str.split(" ").str[2]
raw_data.head()
# Out:
#              시군구     번지   본번  부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200603   10
# 1  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200603   29
# 2  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200604   29
# 3  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200606    1
# 4  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200610   20
#
#          거래금액(만원)  층  건축년도      도로명      시    군    구
# 0          59,500  7  1988  언주로 103  서울특별시  강남구  개포동
# 1          60,000  6  1988  언주로 103  서울특별시  강남구  개포동
# 2          67,000  9  1988  언주로 103  서울특별시  강남구  개포동
# 3          60,000  4  1988  언주로 103  서울특별시  강남구  개포동
# 4          72,250  5  1988  언주로 103  서울특별시  강남구  개포동

# %%
filt = (raw_data['계약일']<10)
raw_data.loc[raw_data[filt].index, '계약일'] = '0' + raw_data['계약일'].astype(str)
raw_data.head()
# Out:
#              시군구     번지   본번  부번             단지명  전용면적(㎡)    계약년월 계약일  \
# 0  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200603  10
# 1  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200603  29
# 2  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200604  29
# 3  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200606  01
# 4  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200610  20
#
#          거래금액(만원)  층  건축년도      도로명      시    군    구
# 0          59,500  7  1988  언주로 103  서울특별시  강남구  개포동
# 1          60,000  6  1988  언주로 103  서울특별시  강남구  개포동
# 2          67,000  9  1988  언주로 103  서울특별시  강남구  개포동
# 3          60,000  4  1988  언주로 103  서울특별시  강남구  개포동
# 4          72,250  5  1988  언주로 103  서울특별시  강남구  개포동

# %%
raw_data['계약년월일']=raw_data['계약년월'].astype(str) + raw_data['계약일'].astype(str)
raw_data.head()
# Out:
#              시군구     번지   본번  부번             단지명  전용면적(㎡)    계약년월 계약일  \
# 0  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200603  10
# 1  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200603  29
# 2  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200604  29
# 3  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200606  01
# 4  서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200610  20
#
#          거래금액(만원)  층  건축년도      도로명      시    군    구     계약년월일
# 0          59,500  7  1988  언주로 103  서울특별시  강남구  개포동  20060310
# 1          60,000  6  1988  언주로 103  서울특별시  강남구  개포동  20060329
# 2          67,000  9  1988  언주로 103  서울특별시  강남구  개포동  20060429
# 3          60,000  4  1988  언주로 103  서울특별시  강남구  개포동  20060601
# 4          72,250  5  1988  언주로 103  서울특별시  강남구  개포동  20061020

# %%
raw_data.head(20)
# Out:
#               시군구     번지   본번  부번             단지명  전용면적(㎡)    계약년월 계약일  \
# 0   서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200603  10
# 1   서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200603  29
# 2   서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200604  29
# 3   서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200606  01
# 4   서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200610  20
# 5   서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200610  30
# 6   서울특별시 강남구 개포동  655-2  655   2  개포2차현대아파트(220)    77.75  200612  09
# 7   서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동    67.28  200601  19
# 8   서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동    79.97  200601  21
# 9   서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동    79.97  200601  25
# 10  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동    79.97  200602  01
# 11  서울특별시 강남구 개포동  658-1  658   1  개포6차우성아파트1동~8동    79.97  200603  02
# ...

# %%
raw_data.drop(['시군구','계약년월','계약일'],1, inplace=True)
raw_data.head()
# Out:
#       번지   본번  부번             단지명  전용면적(㎡)        거래금액(만원)  층  건축년도      도로명  \
# 0  655-2  655   2  개포2차현대아파트(220)    77.75          59,500  7  1988  언주로 103
# 1  655-2  655   2  개포2차현대아파트(220)    77.75          60,000  6  1988  언주로 103
# 2  655-2  655   2  개포2차현대아파트(220)    77.75          67,000  9  1988  언주로 103
# 3  655-2  655   2  개포2차현대아파트(220)    77.75          60,000  4  1988  언주로 103
# 4  655-2  655   2  개포2차현대아파트(220)    77.75          72,250  5  1988  언주로 103
#
#        시    군    구     계약년월일
# 0  서울특별시  강남구  개포동  20060310
# 1  서울특별시  강남구  개포동  20060329
# 2  서울특별시  강남구  개포동  20060429
# 3  서울특별시  강남구  개포동  20060601
# 4  서울특별시  강남구  개포동  20061020

# %%
from datetime import datetime

# %%
raw_data['계약년월일'] = pd.to_datetime(raw_data['계약년월일'])

# %%
raw_data['연']=raw_data['계약년월일'].dt.year
raw_data['월']=raw_data['계약년월일'].dt.month
raw_data['일']=raw_data['계약년월일'].dt.day
raw_data.head()
# Out:
#       번지   본번  부번             단지명  전용면적(㎡)        거래금액(만원)  층  건축년도      도로명  \
# 0  655-2  655   2  개포2차현대아파트(220)    77.75          59,500  7  1988  언주로 103
# 1  655-2  655   2  개포2차현대아파트(220)    77.75          60,000  6  1988  언주로 103
# 2  655-2  655   2  개포2차현대아파트(220)    77.75          67,000  9  1988  언주로 103
# 3  655-2  655   2  개포2차현대아파트(220)    77.75          60,000  4  1988  언주로 103
# 4  655-2  655   2  개포2차현대아파트(220)    77.75          72,250  5  1988  언주로 103
#
#        시    군    구      계약년월일     연   월   일
# 0  서울특별시  강남구  개포동 2006-03-10  2006   3  10
# 1  서울특별시  강남구  개포동 2006-03-29  2006   3  29
# 2  서울특별시  강남구  개포동 2006-04-29  2006   4  29
# 3  서울특별시  강남구  개포동 2006-06-01  2006   6   1
# 4  서울특별시  강남구  개포동 2006-10-20  2006  10  20

# %%
raw_data['uid'] = raw_data['시'] + raw_data['군'] + raw_data['구'] + raw_data['단지명']
raw_data.head()
# Out:
#       번지   본번  부번             단지명  전용면적(㎡)        거래금액(만원)  층  건축년도      도로명  \
# 0  655-2  655   2  개포2차현대아파트(220)    77.75          59,500  7  1988  언주로 103
# 1  655-2  655   2  개포2차현대아파트(220)    77.75          60,000  6  1988  언주로 103
# 2  655-2  655   2  개포2차현대아파트(220)    77.75          67,000  9  1988  언주로 103
# 3  655-2  655   2  개포2차현대아파트(220)    77.75          60,000  4  1988  언주로 103
# 4  655-2  655   2  개포2차현대아파트(220)    77.75          72,250  5  1988  언주로 103
#
#        시    군    구      계약년월일     연   월   일                        uid
# 0  서울특별시  강남구  개포동 2006-03-10  2006   3  10  서울특별시강남구개포동개포2차현대아파트(220)
# 1  서울특별시  강남구  개포동 2006-03-29  2006   3  29  서울특별시강남구개포동개포2차현대아파트(220)
# 2  서울특별시  강남구  개포동 2006-04-29  2006   4  29  서울특별시강남구개포동개포2차현대아파트(220)
# 3  서울특별시  강남구  개포동 2006-06-01  2006   6   1  서울특별시강남구개포동개포2차현대아파트(220)
# 4  서울특별시  강남구  개포동 2006-10-20  2006  10  20  서울특별시강남구개포동개포2차현대아파트(220)

# %%
raw_data['단지명'].nunique()
# Out:
# 7288

# %%
raw_data['단지명'].value_counts()
# Out:
# 현대                12645
# 두산                 8743
# 한신                 8566
# 주공2                8145
# 신동아                7599
#                   ...
# (717-15)경원주택5동        1
# A파크                   1
# (791-18)              1
# 밀란체                   1
# 계영주택(746-49)          1
# Name: 단지명, Length: 7288, dtype: int64

# %%
raw_data['단지명'].value_counts()[raw_data['단지명'].value_counts() < 10].index
# Out:
# Index(['경동미르웰', '대치하나빌', '방배2차상지리츠빌', '한아(987-21)', '방배아펠바움', '삼성그랑빌',
#        '(246-11)', '리치빌(177-2)', '장안트윈A(306-8)', '미래하이츠',
#        ...
#        '은평뉴타운 박석고개(힐스테이트12단지임대)', '명수대', '(749-44)', '대호드림빌(38-213)', '휘경 SK뷰',
#        '(717-15)경원주택5동', 'A파크', '(791-18)', '밀란체', '계영주택(746-49)'],
#       dtype='object', length=1506)

# %%
raw_data['uid'].nunique()
# Out:
# 8584

# %% [markdown]
# #### 서울특별시의 아파트 단지수는 2,404
# - cf. [K-apt](http://www.k-apt.go.kr/cmmn/kaptworkintro.do)
# - 추가적으로 더 줄일 수 있는 feature를 찾아야 한다.

# %%
raw_data = raw_data[['거래금액(만원)','uid','단지명','전용면적(㎡)','층',
                     '건축년도','계약년월일','연','월','일',
                     '시','군','구','번지','본번','부번','도로명']]

# %%
raw_data
# Out:
#                거래금액(만원)                        uid             단지명  전용면적(㎡)  \
# 0                59,500  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# 1                60,000  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# 2                67,000  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# 3                60,000  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# 4                72,250  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# ...                 ...                        ...             ...      ...
# 1061830          44,500             서울특별시중랑구중화동한신2             한신2    59.76
# 1061831          35,000         서울특별시중랑구중화동한영(101)         한영(101)    84.69
# 1061832          25,800         서울특별시중랑구중화동한영(102)         한영(102)    57.18
# 1061833          34,500           서울특별시중랑구중화동현대휴앤미           현대휴앤미    82.17
# 1061834          32,800     서울특별시중랑구중화동현대휴앤미(102동)     현대휴앤미(102동)    64.48
#
# ...

# %%
apartment = pd.read_csv('./apart_price_raw_2006-2019.csv')

# %%
apartment
# Out:
#                거래금액(만원)                        uid             단지명  전용면적(㎡)  \
# 0                59,500  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# 1                60,000  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# 2                67,000  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# 3                60,000  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# 4                72,250  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# ...                 ...                        ...             ...      ...
# 1061830          44,500             서울특별시중랑구중화동한신2             한신2    59.76
# 1061831          35,000         서울특별시중랑구중화동한영(101)         한영(101)    84.69
# 1061832          25,800         서울특별시중랑구중화동한영(102)         한영(102)    57.18
# 1061833          34,500           서울특별시중랑구중화동현대휴앤미           현대휴앤미    82.17
# 1061834          32,800     서울특별시중랑구중화동현대휴앤미(102동)     현대휴앤미(102동)    64.48
#
# ...

# %%
def reduce_mem_usage(props):
    start_mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage of properties dataframe is :",start_mem_usg," MB")
    NAlist = [] # Keeps track of columns that have missing values filled in. 
    for col in props.columns:
        if props[col].dtype != object:  # Exclude strings

            # Print current column type
            print("******************************")
            print("Column: ",col)
            print("dtype before: ",props[col].dtype)

            # make variables for Int, max and min
            IsInt = False
            mx = props[col].max()
            mn = props[col].min()

            # Integer does not support NA, therefore, NA needs to be filled
            if not np.isfinite(props[col]).all(): 
                NAlist.append(col)
                props[col].fillna(mn-1,inplace=True)  

            # test if column can be converted to an integer
            asint = props[col].fillna(0).astype(np.int64)
            result = (props[col] - asint)
            result = result.sum()
            if result > -0.01 and result < 0.01:
                IsInt = True


            # Make Integer/unsigned Integer datatypes
            if IsInt:
                if mn >= 0:
                    if mx < 255:
                        props[col] = props[col].astype(np.uint8)
                    elif mx < 65535:
                        props[col] = props[col].astype(np.uint16)
                    elif mx < 4294967295:
                        props[col] = props[col].astype(np.uint32)
                    else:
                        props[col] = props[col].astype(np.uint64)
                else:
                    if mn > np.iinfo(np.int8).min and mx < np.iinfo(np.int8).max:
                        props[col] = props[col].astype(np.int8)
                    elif mn > np.iinfo(np.int16).min and mx < np.iinfo(np.int16).max:
                        props[col] = props[col].astype(np.int16)
                    elif mn > np.iinfo(np.int32).min and mx < np.iinfo(np.int32).max:
                        props[col] = props[col].astype(np.int32)
                    elif mn > np.iinfo(np.int64).min and mx < np.iinfo(np.int64).max:
                        props[col] = props[col].astype(np.int64)    

            # Make float datatypes 32 bit
            else:
                props[col] = props[col].astype(np.float32)

            # Print new column type
            print("dtype after: ",props[col].dtype)
            print("******************************")

    # Print final result
    print("___MEMORY USAGE AFTER COMPLETION:___")
    mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage is: ",mem_usg," MB")
    print("This is ",100*mem_usg/start_mem_usg,"% of the initial size")
    return props, NAlist

# %%
props, NAlist = reduce_mem_usage(apartment)
# Out:
# Memory usage of properties dataframe is : 137.71981048583984  MB
# ******************************
# Column:  전용면적(㎡)
# dtype before:  float64
# dtype after:  float32
# ******************************
# ******************************
# Column:  층
# dtype before:  int64
# dtype after:  int8
# ******************************
# ******************************
# Column:  건축년도
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  연
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  월
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  일
# dtype before:  int64
# dtype after:  uint8
# ******************************
# ******************************
# Column:  본번
# dtype before:  int64
# dtype after:  uint16
# ******************************
# ******************************
# Column:  부번
# ...

# %%
apartment.to_csv("apartment_raw_2006-2019.csv", index=False)

# %%
raw_data.to_csv("apart_price_raw_2006-2019.csv",index=False)

# %%
apartment = pd.read_csv('./apart_price_raw_2006-2019.csv')

# %%
apartment
# Out:
#                거래금액(만원)                        uid             단지명  전용면적(㎡)  \
# 0                59,500  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# 1                60,000  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# 2                67,000  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# 3                60,000  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# 4                72,250  서울특별시강남구개포동개포2차현대아파트(220)  개포2차현대아파트(220)    77.75
# ...                 ...                        ...             ...      ...
# 1061830          44,500             서울특별시중랑구중화동한신2             한신2    59.76
# 1061831          35,000         서울특별시중랑구중화동한영(101)         한영(101)    84.69
# 1061832          25,800         서울특별시중랑구중화동한영(102)         한영(102)    57.18
# 1061833          34,500           서울특별시중랑구중화동현대휴앤미           현대휴앤미    82.17
# 1061834          32,800     서울특별시중랑구중화동현대휴앤미(102동)     현대휴앤미(102동)    64.48
#
# ...

# %% [markdown]
# ------------------------------

# %%
year_list = ["price_%d" % x for x in range(2006,2020)]
year_list

# %%
year_list = [yr for yr in range(2006,2020)]
year_list

# %%
# %%time
for i in tqdm(range(2006,2020)):
    for k in d_list:
        k = price_table(i)

# %%
# %%time
for k in d_list:
    for i in tqdm(range(2006,2020)):
        k = price_table(i)

# %%
for i in tqdm(range(2006,2020)):
    price_title = 'price_'+ '{}'.format(i)
#     price_table(i)
    'price_{i}'.format(i) = price_table(i)

# %%
d_list=list(d.keys())
d_list

# %%
for key, value in d.items():
    key = value
    print(key, value)

# %%
d['price_2019'].dtypes

# %%
for i in range(2009,2020):
    price_a='price_{}'.format(i)
    price_a = d['price_{}'.format(i)]
